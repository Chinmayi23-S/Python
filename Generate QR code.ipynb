# %%
pip install qrcode pillow
# Out:
# mambajs 0.21.4
#
# Process pip requirements ...
#
# Requirement pillow already handled by conda/micromamba/mamba.
# ...

# %%
import qrcode

url = input("Enter website URL:")

img = qrcode.make(url)
img.save("qr_code.png")

print("QR code created!")
ima
# Out:
# Enter website URL: https://www.magnific.com/free-photo/closeup-shot-beautiful-butterfly-with-interesting-textures-orange-petaled-flower_9183672.htm#fromView=keyword&page=1&position=0&query=Beautiful
# QR code created!
