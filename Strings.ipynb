# %% [markdown]
# 1. Create a string named path_description that describes a Windows file path: C:\Program Files\My App\data.txt. Use raw string notation to avoid issues with backslashes. Print this string.

# %%
#Create a raw string for a Windows file Path
Path_description = r"C:\Program Files\My App\data.txt."
print(Path_description)
# Out:
# C:\Program Files\My App\data.txt.

# %% [markdown]
# 2. Create a string named multiline_quote that includes a newline and a tab, and uses both single and double quotes. The string should look like this when printed:

# %%
# Multiline string with escape characters
multiline_quote = "\"What a wonderful Morning!\"\n \t 'I see the cat chasing small Bee and Birds singing'"
print(multiline_quote)
# Out:
# "What a wonderful Morning!"
#  	 'I see the cat chasing small Bee and Birds singing'

# %% [markdown]
# 3. Take the string secret_message = "Python is fun!".
# Encode this message into bytes using utf-8 encoding and
# store it in a variable called encoded_bytes. Print encoded_bytes.

# %%
secret_message = "Python is fun!"
encoded_bytes = secret_message.encode('utf-8')
print(f"Original message: {secret_message}")
print(f"Encoded_bytes (UTF-8): {encoded_bytes}")
# Out:
# Original message: Python is fun!
# Encoded_bytes (UTF-8): b'Python is fun!'

# %% [markdown]
# 4. Decode encoded_bytes back into a string using utf-8 and store it in decoded_message.
# Print decoded_message.

# %%
decoded
